# %%
import numpy as np

a = np.zeros(3)
type(a)
# Out:
# numpy.ndarray

# %%
b = np.ones(3)
b
# Out:
# array([1., 1., 1.])

# %%
c = np.linspace(2,10,5) #2 to 10 with 5 elements
c
# Out:
# array([ 2.  ,  5.25,  8.5 , 11.75, 15.  ])

# %%
a = np.array([10,20]) #1d array
a
# Out:
# array([[[12, 23, 23],
#         [ 2,  3, 24]]])

# %%
b_list = ([12,23,23],[2,3,24]) #2d array
c = np.array([b_list]) 
c
# Out:
# array([[[12, 23, 23],
#         [ 2,  3, 24]]])

# %%
from skimage import io
photo = io.imread('img1.png')
type(photo)
# Out:
# numpy.ndarray

# %%
photo.shape
# Out:
# (2210, 2000, 3)

# %%
import matplotlib.pyplot as plt
plt.imshow(photo)

# %%
plt.imshow(photo[::-1])

# %%
plt.imshow(photo[:,::-1])

# %%
plt.imshow(photo[50:150, 150:250])

# %%
photo
photo_sin = np.sin(photo)
photo_sin
# Out:
# array([[[ 0.785  ,  0.1847 , -0.89   ],
#         [-0.727  ,  0.623  , -0.9707 ],
#         [-0.0972 , -0.727  , -0.8647 ],
#         ...,
#         [ 0.785  ,  0.1847 , -0.89   ],
#         [ 0.785  ,  0.1847 , -0.89   ],
#         [ 0.785  ,  0.1847 , -0.89   ]],
#
#        [[ 0.785  ,  0.1847 , -0.89   ],
#         [ 0.623  ,  0.9946 ,  0.623  ],
#         [-0.89   , -0.727  , -0.04422],
#         ...,
#         [ 0.785  ,  0.1847 , -0.89   ],
#         [ 0.785  ,  0.1847 , -0.89   ],
#         [ 0.785  ,  0.1847 , -0.89   ]],
#
#        [[ 0.785  ,  0.1847 , -0.89   ],
#         [ 0.785  ,  0.1847 , -0.89   ],
#         [ 0.785  ,  0.1847 , -0.89   ],
#         ...,
#         [ 0.785  ,  0.1847 , -0.89   ],
#         [ 0.785  ,  0.1847 , -0.89   ],
#         [ 0.785  ,  0.1847 , -0.89   ]],
#
#        ...,
#
#        [[ 0.4363 , -0.9165 , -0.4282 ],
#         [ 0.4363 , -0.9165 , -0.4282 ],
#         [ 0.4363 , -0.9165 , -0.4282 ],
#         ...,
# ...

# %%
print(np.sum(photo))
print(np.prod(photo))
print(np.mean(photo))
print(np.std(photo))
print(np.var(photo))
print(np.min(photo))
print(np.max(photo))
print(np.argmin(photo))
print(np.argmax(photo))
# Out:
# 2736810811
# 0
# 206.39598876319758
# 75.97597053282502
# 5772.3480984046955
# 0
# 255
# 294522
# 48

# %%
z = np.array([1,2,3,4,5])
z
# Out:
# array([1, 2, 3, 4, 5])

# %%
z<3
# Out:
# array([ True,  True, False, False, False])

# %%
z>3
# Out:
# array([False, False, False,  True,  True])

# %%
photo = io.imread('img2.jpg')
photo_masked = np.where(photo > 50,255,0) # photo >100 replace with 255 and where !>100 replace with 0

# %%
plt.imshow(photo_masked)

# %%
print(z + 30)
print(z * 30)
# Out:
# [31 32 33 34 35]
# [ 30  60  90 120 150]

# %%
plt.imshow(photo[:,:,0].T) #swap rows and columns
