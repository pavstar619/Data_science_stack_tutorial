# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
a = sns.load_dataset("flights")
sns.relplot(x = "passengers", y = "month", data = a)

# %%
a = sns.load_dataset("flights")
sns.relplot(x = "passengers", y = "month", hue = "year", data = a)

# %%
b = sns.load_dataset("tips")
sns.relplot(x="time",y="tip",data=b,kind="line")

# %%
sns.catplot(x="day",y="total_bill",data=b) #also boxplot,swapplot etc

# %%
sns.catplot(x="day",y="total_bill",kind="boxen",data=b)

# %%
from scipy import stats

# %%
c=np.random.normal(loc=5, size=100, scale=2)
sns.distplot(c)

# %%
'''--MULTI PLOT GIRDS--'''

# %%
a=sns.load_dataset('iris')
b=sns.FacetGrid(a, col='species')
b.map(plt.hist, "sepal_length")
# Out:
# <seaborn.axisgrid.FacetGrid object at 0x15B16460>

# %%
a=sns.load_dataset('flights')
b=sns.PairGrid(a)
b.map(plt.scatter)

# %%
"""Aesthetics"""

# %%
sns.set(style="darkgrid")
a=sns.load_dataset('flights')
b=sns.PairGrid(a)
b.map(plt.scatter)

# %%
sns.set(style="whitegrid",color_codes=True)
a=sns.load_dataset('flights')
b=sns.PairGrid(a)
b.map(plt.scatter)

# %%
c = sns.color_palette()
sns.palplot(c)
